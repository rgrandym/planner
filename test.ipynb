# %%
# Generated by ArchFlow - Mermaid Diagram for Jupyter Notebook
# This code will render a Mermaid flowchart diagram in your notebook

# Method 1: Using IPython Markdown (works in VS Code, JupyterLab with mermaid extension)
from IPython.display import display, Markdown, HTML

mermaid_code = """
graph LR
    PDF_1766770851276[PDF]
    TextProcessing_1766770946298(Text Processing)
    TableExtraction_1766771111115(Table Extraction)
    FormulaParser_1766771168205(Formula Parser)
    OCR_1766771216267(OCR)
    Merge_1766771262023{Merge}
    LLM_1766771340725{{LLM}}
    VectorDB_1766771432912{{Vector DB}}
    JSON_1766771571479[JSON]
    Markdown_1766771576487[Markdown]
    Embedding_1766771701053(Embeddings)

    PDF_1766770851276 --> TextProcessing_1766770946298
    PDF_1766770851276 --> TableExtraction_1766771111115
    PDF_1766770851276 --> FormulaParser_1766771168205
    TableExtraction_1766771111115 --> OCR_1766771216267
    FormulaParser_1766771168205 --> OCR_1766771216267
    OCR_1766771216267 --> Merge_1766771262023
    TextProcessing_1766770946298 --> Merge_1766771262023
    Merge_1766771262023 --> LLM_1766771340725
    LLM_1766771340725 --> Merge_1766771262023
    Merge_1766771262023 --> JSON_1766771571479
    Merge_1766771262023 --> Markdown_1766771576487
    Markdown_1766771576487 --> Embedding_1766771701053
    Embedding_1766771701053 --> VectorDB_1766771432912

    style PDF_1766770851276 fill:#10b981
    style TextProcessing_1766770946298 fill:#f97316
    style TableExtraction_1766771111115 fill:#f97316
    style FormulaParser_1766771168205 fill:#f97316
    style OCR_1766771216267 fill:#f97316
    style Merge_1766771262023 fill:#f59e0b
    style LLM_1766771340725 fill:#8b5cf6
    style VectorDB_1766771432912 fill:#8b5cf6
    style JSON_1766771571479 fill:#10b981
    style Markdown_1766771576487 fill:#10b981
    style Embedding_1766771701053 fill:#8b5cf6
"""

# Try to display using Markdown (requires mermaid extension in JupyterLab)
try:
    display(Markdown(f"```mermaid\n{mermaid_code}\n```"))
except:
    pass

# Method 2: Using mermaid.js CDN (works in any Jupyter environment)
# Uncomment the following to use the CDN-based rendering:
'''
from IPython.display import display, HTML

html_template = f"""
<script src="https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js"></script>
<script>mermaid.initialize({{startOnLoad:true, theme:'dark'}});</script>
<div class="mermaid">
{mermaid_code}
</div>
"""
display(HTML(html_template))
'''
# Out:
# ```mermaid
#
# graph LR
#     PDF_1766770851276[PDF]
#     TextProcessing_1766770946298(Text Processing)
#     TableExtraction_1766771111115(Table Extraction)
#     FormulaParser_1766771168205(Formula Parser)
#     OCR_1766771216267(OCR)
#     Merge_1766771262023{Merge}
#     LLM_1766771340725{{LLM}}
#     VectorDB_1766771432912{{Vector DB}}
#     JSON_1766771571479[JSON]
#     Markdown_1766771576487[Markdown]
#     Embedding_1766771701053(Embeddings)
#
#     PDF_1766770851276 --> TextProcessing_1766770946298
#     PDF_1766770851276 --> TableExtraction_1766771111115
#     PDF_1766770851276 --> FormulaParser_1766771168205
#     TableExtraction_1766771111115 --> OCR_1766771216267
#     FormulaParser_1766771168205 --> OCR_1766771216267
#     OCR_1766771216267 --> Merge_1766771262023
#     TextProcessing_1766770946298 --> Merge_1766771262023
#     Merge_1766771262023 --> LLM_1766771340725
#     LLM_1766771340725 --> Merge_1766771262023
#     Merge_1766771262023 --> JSON_1766771571479
# ...
